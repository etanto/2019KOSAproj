# %%
import pandas as pd

# %% [markdown]
# # 2016년도 데이터 변환.

# %%
df1 = pd.read_sas('hn16_all.sas7bdat')

# %%
df1.head()
# Out:
#             mod_d             ID       ID_fam    year  region  town_t  apt_t  \
# 0  b'2019.03.06.'  b'A651172801'  b'A6511728'  2016.0     1.0     1.0    2.0
# 1  b'2019.03.06.'  b'A651172802'  b'A6511728'  2016.0     1.0     1.0    2.0
# 2  b'2019.03.06.'  b'A651183001'  b'A6511830'  2016.0     1.0     1.0    2.0
# 3  b'2019.03.06.'  b'A651183002'  b'A6511830'  2016.0     1.0     1.0    2.0
# 4  b'2019.03.06.'  b'A651183003'  b'A6511830'  2016.0     1.0     1.0    2.0
#
#        psu  sex   age  ...    N_VA_RAE      N_CAROT    N_RETIN      N_B1  \
# 0  b'A651'  1.0  61.0  ...   68.125541   817.506495   0.000000  1.812120
# 1  b'A651'  2.0  57.0  ...   91.302698  1095.561039   0.005945  1.075103
# 2  b'A651'  2.0  41.0  ...  261.852637  2147.567940  82.888642  1.093273
# 3  b'A651'  1.0  39.0  ...         NaN          NaN        NaN       NaN
# 4  b'A651'  2.0  38.0  ...         NaN          NaN        NaN       NaN
#
# ...

# %%
df1.to_csv('./hn16_all.csv', index = False)

# %%
df2 = pd.read_sas('hn16_24rc.sas7bdat')
df2.head()
# Out:
#             mod_d             ID       ID_fam    year  region  town_t  apt_t  \
# 0  b'2019.03.06.'  b'A651172801'  b'A6511728'  2016.0     1.0     1.0    2.0
# 1  b'2019.03.06.'  b'A651172801'  b'A6511728'  2016.0     1.0     1.0    2.0
# 2  b'2019.03.06.'  b'A651172801'  b'A6511728'  2016.0     1.0     1.0    2.0
# 3  b'2019.03.06.'  b'A651172801'  b'A6511728'  2016.0     1.0     1.0    2.0
# 4  b'2019.03.06.'  b'A651172801'  b'A6511728'  2016.0     1.0     1.0    2.0
#
#        psu  sex   age  ...  NS_WT  NS_CODE  NS_CA  NS_PHOS  NS_FE  NS_VA_RAE  \
# 0  b'A651'  1.0  61.0  ...    NaN      NaN    NaN      NaN    NaN        NaN
# 1  b'A651'  1.0  61.0  ...    NaN      NaN    NaN      NaN    NaN        NaN
# 2  b'A651'  1.0  61.0  ...    NaN      NaN    NaN      NaN    NaN        NaN
# 3  b'A651'  1.0  61.0  ...    NaN      NaN    NaN      NaN    NaN        NaN
# 4  b'A651'  1.0  61.0  ...    NaN      NaN    NaN      NaN    NaN        NaN
#
#    NS_B1  NS_B2  NS_NIAC  NS_VITC
# ...

# %%
df2.to_csv('./hn16_24rc.csv',index= False)

# %%
df3 = pd.read_sas('hn16_ffq.sas7bdat')
df3.head()
# Out:
#             mod_d             ID       ID_fam    year  region  town_t  apt_t  \
# 0  b'2019.03.06.'  b'A651172801'  b'A6511728'  2016.0     1.0     1.0    2.0
# 1  b'2019.03.06.'  b'A651172802'  b'A6511728'  2016.0     1.0     1.0    2.0
# 2  b'2019.03.06.'  b'A651183001'  b'A6511830'  2016.0     1.0     1.0    2.0
# 3  b'2019.03.06.'  b'A651183002'  b'A6511830'  2016.0     1.0     1.0    2.0
# 4  b'2019.03.06.'  b'A651183003'  b'A6511830'  2016.0     1.0     1.0    2.0
#
#        psu  sex   age  ...      FQ_FE        FQ_NA         FQ_K       FQ_VA  \
# 0  b'A651'  1.0  61.0  ...        NaN          NaN          NaN         NaN
# 1  b'A651'  2.0  57.0  ...        NaN          NaN          NaN         NaN
# 2  b'A651'  2.0  41.0  ...  12.879218  3671.647791  2226.426572  459.311661
# 3  b'A651'  1.0  39.0  ...        NaN          NaN          NaN         NaN
# 4  b'A651'  2.0  38.0  ...        NaN          NaN          NaN         NaN
#
# ...

# %%
df3.to_csv('./hn16_ffq.csv',index=False)

# %%
df1.shape, df2.shape, df3.shape
# Out:
# ((8150, 775), (518061, 132), (8150, 438))

# %% [markdown]
# # 2015년도 데이터 변환.

# %%
df4 = pd.read_sas('hn15_all.sas7bdat')
df4.head()
# Out:
#             mod_d             ID       ID_fam    year  region  town_t  apt_t  \
# 0  b'2019.03.06.'  b'A259652214'  b'A2596522'  2015.0     1.0     1.0    1.0
# 1  b'2019.03.06.'  b'A259652215'  b'A2596522'  2015.0     1.0     1.0    1.0
# 2  b'2019.03.06.'  b'A259652216'  b'A2596522'  2015.0     1.0     1.0    1.0
# 3  b'2019.03.06.'  b'A259662312'  b'A2596623'  2015.0     1.0     1.0    1.0
# 4  b'2019.03.06.'  b'A259662313'  b'A2596623'  2015.0     1.0     1.0    1.0
#
#        psu  sex   age  ...  HEI_TVEG   HEI_VEG  HEI_PROTF  HEI_DAIRY  \
# 0  b'A259'  2.0  20.0  ...  5.000000  3.404515  10.000000       10.0
# 1  b'A259'  2.0  47.0  ...  5.000000  5.000000  10.000000        0.0
# 2  b'A259'  2.0  77.0  ...  0.659104  1.318207   6.646070        0.0
# 3  b'A259'  2.0  42.0  ...  4.175217  4.530347   3.516604        0.0
# 4  b'A259'  2.0  14.0  ...       NaN       NaN        NaN        NaN
#
#      HEI_SFA     HEI_NA  HEI_SWEET   HEI_CHO  HEI_FAT    HEI_EN
# ...

# %%
df4.to_csv('./hn15_all.csv',index=False)

# %%
df5 = pd.read_sas('hn15_24rc.sas7bdat')
df5.head()
# Out:
#             mod_d             ID       ID_fam    year  region  town_t  apt_t  \
# 0  b'2019.03.06.'  b'A259652214'  b'A2596522'  2015.0     1.0     1.0    1.0
# 1  b'2019.03.06.'  b'A259652214'  b'A2596522'  2015.0     1.0     1.0    1.0
# 2  b'2019.03.06.'  b'A259652214'  b'A2596522'  2015.0     1.0     1.0    1.0
# 3  b'2019.03.06.'  b'A259652214'  b'A2596522'  2015.0     1.0     1.0    1.0
# 4  b'2019.03.06.'  b'A259652214'  b'A2596522'  2015.0     1.0     1.0    1.0
#
#        psu  sex   age  ...  NS_WT  NS_CODE  NS_CA  NS_PHOS  NS_FE  NS_VA  \
# 0  b'A259'  2.0  20.0  ...    NaN      NaN    NaN      NaN    NaN    NaN
# 1  b'A259'  2.0  20.0  ...    NaN      NaN    NaN      NaN    NaN    NaN
# 2  b'A259'  2.0  20.0  ...    NaN      NaN    NaN      NaN    NaN    NaN
# 3  b'A259'  2.0  20.0  ...    NaN      NaN    NaN      NaN    NaN    NaN
# 4  b'A259'  2.0  20.0  ...    NaN      NaN    NaN      NaN    NaN    NaN
#
#    NS_B1  NS_B2  NS_NIAC  NS_VITC
# ...

# %%
df5.to_csv('./hn15_24rc.csv',index=False)

# %%
df6 = pd.read_sas('hn15_ffq.sas7bdat')
df6.head()
# Out:
#             mod_d             ID       ID_fam    year  region  town_t  apt_t  \
# 0  b'2019.03.06.'  b'A259652214'  b'A2596522'  2015.0     1.0     1.0    1.0
# 1  b'2019.03.06.'  b'A259652215'  b'A2596522'  2015.0     1.0     1.0    1.0
# 2  b'2019.03.06.'  b'A259652216'  b'A2596522'  2015.0     1.0     1.0    1.0
# 3  b'2019.03.06.'  b'A259662312'  b'A2596623'  2015.0     1.0     1.0    1.0
# 4  b'2019.03.06.'  b'A259662313'  b'A2596623'  2015.0     1.0     1.0    1.0
#
#        psu  sex   age  ...      FQ_FE        FQ_NA         FQ_K        FQ_VA  \
# 0  b'A259'  2.0  20.0  ...  22.995561  8110.086972  4753.526861  1217.375464
# 1  b'A259'  2.0  47.0  ...  13.340067  4227.652452  1940.653351   587.318931
# 2  b'A259'  2.0  77.0  ...        NaN          NaN          NaN          NaN
# 3  b'A259'  2.0  42.0  ...  11.946455  2834.306675  2021.351581   535.774362
# 4  b'A259'  2.0  14.0  ...        NaN          NaN          NaN          NaN
#
# ...

# %%
df6.to_csv('./hn15_ffq.csv',index=False)

# %%
df4.shape, df5.shape, df6.shape
# Out:
# ((7380, 786), (447718, 128), (7380, 436))

# %% [markdown]
# # 2014년도 데이터 변환.

# %%
df7 = pd.read_sas('hn14_all.sas7bdat')
df7.head()
# Out:
#             mod_d             ID       ID_fam    year  region  town_t  apt_t  \
# 0  b'2019.03.06.'  b'A209716213'  b'A2097162'  2014.0     1.0     1.0    1.0
# 1  b'2019.03.06.'  b'A209716214'  b'A2097162'  2014.0     1.0     1.0    1.0
# 2  b'2019.03.06.'  b'A209716216'  b'A2097162'  2014.0     1.0     1.0    1.0
# 3  b'2019.03.06.'  b'A209724716'  b'A2097247'  2014.0     1.0     1.0    1.0
# 4  b'2019.03.06.'  b'A209731515'  b'A2097315'  2014.0     1.0     1.0    1.0
#
#        psu  sex   age  ...  HEI_TVEG   HEI_VEG  HEI_PROTF  HEI_DAIRY  HEI_SFA  \
# 0  b'A209'  2.0  30.0  ...   5.00000  5.000000   7.548706        0.0     10.0
# 1  b'A209'  2.0  56.0  ...   5.00000  5.000000   6.769070        0.0     10.0
# 2  b'A209'  1.0  29.0  ...   5.00000  5.000000   8.626120       10.0     10.0
# 3  b'A209'  1.0  65.0  ...   2.49922  3.273753  10.000000        0.0     10.0
# 4  b'A209'  2.0  57.0  ...       NaN       NaN        NaN        NaN      NaN
#
# ...

# %%
df7.to_csv('./hn14_all.csv',index=False)

# %%
df8 = pd.read_sas('hn14_24rc.sas7bdat')
df8.head()
# Out:
#             mod_d             ID       ID_fam    year  region  town_t  apt_t  \
# 0  b'2019.03.06.'  b'A209716213'  b'A2097162'  2014.0     1.0     1.0    1.0
# 1  b'2019.03.06.'  b'A209716213'  b'A2097162'  2014.0     1.0     1.0    1.0
# 2  b'2019.03.06.'  b'A209716213'  b'A2097162'  2014.0     1.0     1.0    1.0
# 3  b'2019.03.06.'  b'A209716213'  b'A2097162'  2014.0     1.0     1.0    1.0
# 4  b'2019.03.06.'  b'A209716213'  b'A2097162'  2014.0     1.0     1.0    1.0
#
#        psu  sex   age  ...     NF_FE      NF_NA        NF_K       NF_VA  \
# 0  b'A209'  2.0  30.0  ...  1.202830  95.518868  104.716981   61.556604
# 1  b'A209'  2.0  30.0  ...  0.840906  23.124906  175.013491    3.153396
# 2  b'A209'  2.0  30.0  ...  0.005660   0.056604    3.353774    0.028302
# 3  b'A209'  2.0  30.0  ...  0.347434   1.737170  172.558868    0.000000
# 4  b'A209'  2.0  30.0  ...  1.159670  33.398491  276.001415  221.265000
#
#       NF_CAROT   NF_RETIN     NF_B1     NF_B2   NF_NIAC    NF_VITC
# ...

# %%
df8.to_csv('./hn14_24rc.csv',index=False)

# %%
df9 = pd.read_sas('hn14_ffq.sas7bdat')
df9.head()
# Out:
#             mod_d             ID       ID_fam    year  region  town_t  apt_t  \
# 0  b'2019.03.06.'  b'A209716213'  b'A2097162'  2014.0     1.0     1.0    1.0
# 1  b'2019.03.06.'  b'A209716214'  b'A2097162'  2014.0     1.0     1.0    1.0
# 2  b'2019.03.06.'  b'A209716216'  b'A2097162'  2014.0     1.0     1.0    1.0
# 3  b'2019.03.06.'  b'A209724716'  b'A2097247'  2014.0     1.0     1.0    1.0
# 4  b'2019.03.06.'  b'A209731515'  b'A2097315'  2014.0     1.0     1.0    1.0
#
#        psu  sex   age  ...      FQ_FE        FQ_NA         FQ_K       FQ_VA  \
# 0  b'A209'  2.0  30.0  ...  10.838058  2894.805178  1807.751695  432.244331
# 1  b'A209'  2.0  56.0  ...   9.566299  2232.057108  2525.239874  560.070765
# 2  b'A209'  1.0  29.0  ...  12.311612  2797.995657  2701.107022  527.473280
# 3  b'A209'  1.0  65.0  ...        NaN          NaN          NaN         NaN
# 4  b'A209'  2.0  57.0  ...        NaN          NaN          NaN         NaN
#
# ...

# %%
df9.to_csv('./hn14_ffq.csv',index=False)

# %%
df7.shape, df8.shape, df9.shape
# Out:
# ((7550, 746), (446753, 113), (7550, 436))
